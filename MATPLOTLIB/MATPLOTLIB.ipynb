# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is the most popular plotting library for Python.
# It gives you control over every aspect of a figure.
# It was designed to have a similar feel to matlab's graphical plotting

# %% [markdown]
# # Importing

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 
# this will help to run matplotlib inside jupyter notebook

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
# functional method
plt.plot(x,y)
#plt.show() # its like printing the plot. 
# If you are using any other ide other than jupyter then use this command

# %%
plt.plot(x,y,"r*")

# %%
plt.xlabel('x') # gives x-axis label name
plt.ylabel('y') # gives y-axis label name
plt.title('Title')  # gives title of the plot
plt.plot(x,y,"r*") # returns the type of plot

# %% [markdown]
# Subplots

# %%
plt.subplot(1,2,1) 
# this will create a new plot on the canvas at first row and first column with the first index
plt.plot(x,y,'r')
plt.subplot(1,2,2)
# this will create a new plot on the canvas at first row and first column with the second index
plt.plot(y,x,'b')

# %% [markdown]
# ## Object Oriented Plotting

# %%
fig = plt.figure() 
# if you run this cell, notice a figure object has been created in this cell
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
axes1 =fig.add_axes([0.1,0.1,0.8,0.8])
axes2 =fig.add_axes([0.3,0.5,0.4,0.3])

# %%
fig = plt.figure()
axes1 =fig.add_axes([0.1,0.1,0.8,0.8])
axes2 =fig.add_axes([0.4,0.3,0.2,0.4])
# moves the plot in left,right,width,height
