# %% [markdown]
# # Pandas visualization Built-In

# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)
# this command will set the date row as row header
ddf1 = pd.read_csv('df1')
#ddf1
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins = 30) #  
# this command will directly give a histogram of the A column with respect to index
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha = 0.4) 
# just a line plot and the area under it has been filled with color
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins =20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(x = 'A',y = 'B',figsize =(12,3),linewidth = 1)
# Out:
# <AxesSubplot:xlabel='A'>

# %%
df1.plot.scatter(x='A',y ='B', c ='C',cmap = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box() # takes a column and plots the data distribution on the data distribution
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns = ['a','b'])
df
# Out:
#             a         b
# 0    0.207458 -2.209556
# 1    0.787831  0.433868
# 2   -1.674697  0.330538
# 3    0.688250 -0.170291
# 4   -0.366776  1.424880
# ..        ...       ...
# 995 -0.654268 -0.531045
# 996  0.871969  0.407607
# 997  0.460063  0.135898
# 998 -0.386112 -0.038152
# 999  2.129382 -0.012066
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x = 'a',y='b',gridsize = 25,cmap = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# or 
df2.plot.density() # plots kde of all plots in the dataframe
# Out:
# <AxesSubplot:ylabel='Density'>
